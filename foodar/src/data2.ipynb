# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as mp
import seaborn as sns

# %%
df = pd.read_csv("cleaned_full_data.csv")

# %%
df = df.dropna()

# %%
df = df.replace("Branpton", "Brampton")

# %%
df = df.dropna()

# %%
df.head()
# Out:
#    Unnamed: 0                restaurant  \
# 0           0                 Sector 17
# 1           1  Golden Palace Restaurant
# 2           2                McDonald's
# 3           3       San Francisco Place
# 4           4           THE BURGER BROS
#
#                                                  url  distance  star  \
# 0  https://www.doordash.com/store/884779/?pickup=...      0.90   4.0
# 1  https://www.doordash.com/store/332454/?pickup=...      2.00   4.0
# 2  https://www.doordash.com/store/1140537/?pickup...      1.00   4.2
# 3  https://www.doordash.com/store/205349/?pickup=...      0.40   4.4
# 4  https://www.doordash.com/store/940617/?pickup=...      0.09   4.5
#
#    num_reviews      city price_range category_1  category_2
# 0        640.0  Brampton          $$     Indian       Wraps
# 1        301.0  Brampton          $$    Chinese     Chicken
# 2        890.0  Brampton          $$     Bakery     Chicken
# 3        109.0  Brampton           $    Italian  Sandwiches
# 4        481.0  Brampton          $$  Fast Food  Sandwiches

# %%
df = df.drop("distance", axis=1)

# %%
df = df.drop("Unnamed: 0", axis=1)

# %%
ch = "\""
for row in df["restaurant"]:
    if ch in row:
        df = df.drop(row.index)

# %%
df
# Out:
#                                    restaurant  \
# 0                                   Sector 17
# 1                    Golden Palace Restaurant
# 2                                  McDonald's
# 3                         San Francisco Place
# 4                             THE BURGER BROS
# ...                                       ...
# 3278  Marcello's Market and Deli (Lombard Pl)
# 3283                               Jennybakes
# 3284              The Taj East Indian Cuisine
# 3286                             Raffy's Cafe
# 3287                              AFV KITCHEN
#
#                                                     url  star  num_reviews  \
# 0     https://www.doordash.com/store/884779/?pickup=...   4.0        640.0
# 1     https://www.doordash.com/store/332454/?pickup=...   4.0        301.0
# 2     https://www.doordash.com/store/1140537/?pickup...   4.2        890.0
# 3     https://www.doordash.com/store/205349/?pickup=...   4.4        109.0
# 4     https://www.doordash.com/store/940617/?pickup=...   4.5        481.0
# ...                                                 ...   ...          ...
# 3278  https://www.doordash.com/store/577047/?pickup=...   4.6         12.0
# 3283  https://www.doordash.com/store/1669010/?pickup...   5.0         30.0
# 3284  https://www.doordash.com/store/853919/?pickup=...   3.1         18.0
# 3286  https://www.doordash.com/store/1653918/?pickup...   4.4         39.0
# 3287  https://www.doordash.com/store/656586/?pickup=...   4.5         58.0
#
#           city price_range   category_1  category_2
# 0     Brampton          $$       Indian       Wraps
# 1     Brampton          $$      Chinese     Chicken
# 2     Brampton          $$       Bakery     Chicken
# 3     Brampton           $      Italian  Sandwiches
# 4     Brampton          $$    Fast Food  Sandwiches
# ...        ...         ...          ...         ...
# 3278  Winnipeg          $$     American  Sandwiches
# 3283  Winnipeg          $$     Desserts  Cheesecake
# 3284  Winnipeg          $$       Indian  Vegetarian
# 3286  Winnipeg          $$     Filipino   Breakfast
# 3287  Winnipeg          $$  Steakhouses     African
#
# [2570 rows x 8 columns]

# %%
df.to_json(r'/Users/raghavv/VS Code/ProjectProgram/data2.json')
